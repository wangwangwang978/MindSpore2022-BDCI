# %%
#导入代码和数据
import os
import moxing as mox
data_obs_url = 'obs://bdci2022/unet_result' 
data_local_url = './'
mox.file.copy_parallel(data_obs_url,data_local_url)
print('代码和数据导入完成....')
# Out:
# INFO:root:Using MoXing-v2.0.0.rc2.4b57a67b-4b57a67b
# INFO:root:Using OBS-Python-SDK-3.20.9.1
# INFO:root:Listing OBS: 1000
# INFO:root:Listing OBS: 2000
# INFO:root:Listing OBS: 3000
# INFO:root:Listing OBS: 4000
# INFO:root:Listing OBS: 5000
# INFO:root:Listing OBS: 6000
# INFO:root:Listing OBS: 7000
# INFO:root:Listing OBS: 8000
# INFO:root:Listing OBS: 9000
# INFO:root:Listing OBS: 10000
# INFO:root:Listing OBS: 11000
# INFO:root:Listing OBS: 12000
# INFO:root:Listing OBS: 13000
# INFO:root:Listing OBS: 14000
# INFO:root:pid: None.	1000/13582
# INFO:root:pid: None.	2000/13582
# INFO:root:pid: None.	3000/13582
# INFO:root:pid: None.	4000/13582
# INFO:root:pid: None.	5000/13582
# INFO:root:pid: None.	6000/13582
# INFO:root:pid: None.	7000/13582
# INFO:root:pid: None.	8000/13582
# INFO:root:pid: None.	9000/13582
# INFO:root:pid: None.	10000/13582
# INFO:root:pid: None.	11000/13582
# INFO:root:pid: None.	12000/13582
# INFO:root:pid: None.	13000/13582
# 代码和数据导入完成....

# %%
#导入代码和数据
import os
import moxing as mox
data_obs_url = 'obs://bdci2022/unet_submit/download.zip' 
data_local_url = './download.zip'
mox.file.copy_parallel(data_local_url, data_obs_url)
print('代码和数据导出完成....')
# Out:
# 代码和数据导出完成....
